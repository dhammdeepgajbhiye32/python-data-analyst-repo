# %%
# Question 5: Calculate rolling averages for a list of numbers.

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\dhamm\\Downloads\\archive\\athlete_events.csv")
df
