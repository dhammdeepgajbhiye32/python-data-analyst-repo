# %%
# Question 3: Create a Pivot table with aggregation function.

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\dhamm\\Downloads\\archive\\athlete_events.csv")
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Creating a Pivot table with aggregation function
from pandas import pivot_table


pivot_table = df.pivot_table(index='Sport', columns='Year', values='Height')
pivot_table.head()
# Out:
# Year                 1896        1900        1904        1906        1908  \
# Sport
# Alpine Skiing         NaN         NaN         NaN         NaN         NaN
# Archery               NaN         NaN  169.875000         NaN         NaN
# Art Competitions      NaN         NaN         NaN         NaN         NaN
# Athletics         174.875  178.578947  178.227273  180.352941  178.305994
# Badminton             NaN         NaN         NaN         NaN         NaN
#
# Year                    1912        1920        1924        1928        1932  \
# Sport
# Alpine Skiing            NaN         NaN         NaN         NaN         NaN
# Archery                  NaN         NaN         NaN         NaN         NaN
# Art Competitions         NaN         NaN  173.555556  169.000000  174.952381
# Athletics         178.129032  177.161194  176.324257  176.472505  176.091765
# Badminton                NaN         NaN         NaN         NaN         NaN
#
# ...
