# %%
# Question 4: Merging two DataFrames by inner join

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\dhamm\\Downloads\\sample_data.csv")
df
# Out:
#    OrderID Customer         Category Region  Sales  Quantity  Profit  \
# 0     1001     Amit       Technology   West  25000         2    5000
# 1     1002     Riya        Furniture   East  18000         3    3000
# 2     1003    Rahul  Office Supplies  North   4000         5     800
# 3     1004    Priya       Technology  South  32000         1    7000
# 4     1005    Sneha        Furniture   West  15000         2    2500
# 5     1006    Arjun  Office Supplies   East   6000         4    1200
# 6     1007    Kiran       Technology  North  28000         3    6000
# 7     1008     Neha        Furniture  South  20000         2    3500
# 8     1009    Rohit  Office Supplies   West   5000         6     900
# 9     1010    Pooja       Technology   East  35000         1    8000
#
#     OrderDate
# 0  10-01-2023
# 1  15-02-2023
# 2  20-02-2023
# 3  05-03-2023
# 4  18-03-2023
# 5  10-04-2023
# 6  22-05-2023
# 7  30-06-2023
# 8  12-07-2023
# 9  25-08-2023

# %%
df2 = pd.read_csv("C:\\Users\\dhamm\\Downloads\\Sample_data.csv")
df2.drop([5,3,6,7,9],inplace=True)
df2
# Out:
#    OrderID Customer         Category Region  Sales  Quantity  Profit  \
# 0     1001     Amit       Technology   West  25000         2    5000
# 1     1002     Riya        Furniture   East  18000         3    3000
# 2     1003    Rahul  Office Supplies  North   4000         5     800
# 4     1005    Sneha        Furniture   West  15000         2    2500
# 8     1009    Rohit  Office Supplies   West   5000         6     900
#
#     OrderDate
# 0  10-01-2023
# 1  15-02-2023
# 2  20-02-2023
# 4  18-03-2023
# 8  12-07-2023

# %%
# Performing inner join on 'OrderID' column
merged_df = pd.merge(df,df2, on='Customer', how = 'inner')
print("Merged DataFrame (Inner Join on 'OrderID'):")
merged_df
# Out:
# Merged DataFrame (Inner Join on 'OrderID'):
#    OrderID_x Customer       Category_x Region_x  Sales_x  Quantity_x  \
# 0       1001     Amit       Technology     West    25000           2
# 1       1002     Riya        Furniture     East    18000           3
# 2       1003    Rahul  Office Supplies    North     4000           5
# 3       1005    Sneha        Furniture     West    15000           2
# 4       1009    Rohit  Office Supplies     West     5000           6
#
#    Profit_x OrderDate_x  OrderID_y       Category_y Region_y  Sales_y  \
# 0      5000  10-01-2023       1001       Technology     West    25000
# 1      3000  15-02-2023       1002        Furniture     East    18000
# 2       800  20-02-2023       1003  Office Supplies    North     4000
# 3      2500  18-03-2023       1005        Furniture     West    15000
# 4       900  12-07-2023       1009  Office Supplies     West     5000
#
#    Quantity_y  Profit_y OrderDate_y
# 0           2      5000  10-01-2023
# ...
