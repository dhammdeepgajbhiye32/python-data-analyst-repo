# %%
# Question3 : Extract first 3 element form an array

# %%
import numpy as np

array = np.array([1,2,3,4,5,6,7,8])

print(f"The original array is: \n {array}")

print(f"The first 3 element are: \n {array[:3]}")
# Out:
# The original array is:
#  [1 2 3 4 5 6 7 8]
# The first 3 element are:
#  [1 2 3]
