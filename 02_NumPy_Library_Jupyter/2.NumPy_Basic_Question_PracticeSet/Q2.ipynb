# %%
# Question2 : Covert a Python list [4,6,8,10] into a NumPy array.

# %%
import numpy as np

list = [4,6,8,10]
print(f"The list is: \n{list}")

numPyArray = np.array(list)

print(f"The NumPy Array is : \n{numPyArray}")
# Out:
# The list is:
# [4, 6, 8, 10]
# The NumPy Array is :
# [ 4  6  8 10]
